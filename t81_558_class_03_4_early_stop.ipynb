# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_4_early_stop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 3: Introduction to TensorFlow**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 3 Material
#
# * Part 3.1: Deep Learning and Neural Network Introduction [[Video]](https://www.youtube.com/watch?v=zYnI4iWRmpc&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_1_neural_net.ipynb)
# * Part 3.2: Introduction to Tensorflow and Keras [[Video]](https://www.youtube.com/watch?v=PsE73jk55cE&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_2_keras.ipynb)
# * Part 3.3: Saving and Loading a Keras Neural Network [[Video]](https://www.youtube.com/watch?v=-9QfbGM1qGw&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_3_save_load.ipynb)
# * **Part 3.4: Early Stopping in Keras to Prevent Overfitting** [[Video]](https://www.youtube.com/watch?v=m1LNunuI2fk&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_4_early_stop.ipynb)
# * Part 3.5: Extracting Weights and Manual Calculation [[Video]](https://www.youtube.com/watch?v=7PWgx16kH8s&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_5_weights.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Note: using Google CoLab

# %% [markdown]
# # Part 3.4: Early Stopping in Keras to Prevent Overfitting
#
# It can be difficult to determine how many epochs to cycle through to train a neural network. Overfitting will occur if you train the neural network for too many epochs, and the neural network will not perform well on new data, despite attaining a good accuracy on the training set. Overfitting occurs when a neural network is trained to the point that it begins to memorize rather than generalize, as demonstrated in Figure 3.OVER.
#
# **Figure 3.OVER: Training vs. Validation Error for Overfitting**
# ![Training vs. Validation Error for Overfitting](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_3_training_val.png "Training vs. Validation Error for Overfitting")
#
# It is important to segment the original dataset into several datasets:
#
# * **Training Set**
# * **Validation Set**
# * **Holdout Set**
#
# You can construct these sets in several different ways. The following programs demonstrate some of these.
#
# The first method is a training and validation set. We use the training data to train the neural network until the validation set no longer improves. This attempts to stop at a near-optimal training point. This method will only give accurate "out of sample" predictions for the validation set; this is usually 20% of the data. The predictions for the training data will be overly optimistic, as these were the data that we used to train the neural network. Figure 3.VAL demonstrates how we divide the dataset.
#
# **Figure 3.VAL: Training with a Validation Set**
# ![Training with a Validation Set](https://raw.githubusercontent.com/jeffheaton/t81_558_deep_learning/master/images/class_1_train_val.png "Training with a Validation Set")

# %% [markdown]
# ## Early Stopping with Classification
#
# We will now see an example of classification training with early stopping. We will train the neural network until the error no longer improves on the validation set.

# %%
import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris.csv", 
    na_values=['NA', '?'])

# Convert to numpy - Classification
x = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Classification
species = dummies.columns
y = dummies.values

# Split into validation and training sets
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Build neural network
model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(y.shape[1],activation='softmax')) # Output
model.compile(loss='categorical_crossentropy', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, 
        verbose=1, mode='auto', restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor],verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 4/4 - 2s - loss: 1.5059 - val_loss: 1.3227 - 2s/epoch - 432ms/step
# Epoch 2/1000
# 4/4 - 0s - loss: 1.2210 - val_loss: 1.0968 - 61ms/epoch - 15ms/step
# Epoch 3/1000
# 4/4 - 0s - loss: 1.0203 - val_loss: 0.9491 - 61ms/epoch - 15ms/step
# Epoch 4/1000
# 4/4 - 0s - loss: 0.9103 - val_loss: 0.8706 - 59ms/epoch - 15ms/step
# Epoch 5/1000
# 4/4 - 0s - loss: 0.8604 - val_loss: 0.8228 - 74ms/epoch - 19ms/step
# Epoch 6/1000
# 4/4 - 0s - loss: 0.8255 - val_loss: 0.7843 - 58ms/epoch - 15ms/step
# Epoch 7/1000
# 4/4 - 0s - loss: 0.7904 - val_loss: 0.7479 - 58ms/epoch - 15ms/step
# Epoch 8/1000
# 4/4 - 0s - loss: 0.7579 - val_loss: 0.7180 - 70ms/epoch - 18ms/step
# Epoch 9/1000
# 4/4 - 0s - loss: 0.7325 - val_loss: 0.6911 - 83ms/epoch - 21ms/step
# Epoch 10/1000
# 4/4 - 0s - loss: 0.7091 - val_loss: 0.6659 - 95ms/epoch - 24ms/step
# Epoch 11/1000
# 4/4 - 0s - loss: 0.6859 - val_loss: 0.6425 - 63ms/epoch - 16ms/step
# Epoch 12/1000
# 4/4 - 0s - loss: 0.6650 - val_loss: 0.6190 - 46ms/epoch - 11ms/step
# Epoch 13/1000
# 4/4 - 0s - loss: 0.6438 - val_loss: 0.5972 - 46ms/epoch - 12ms/step
# Epoch 14/1000
# 4/4 - 0s - loss: 0.6236 - val_loss: 0.5777 - 43ms/epoch - 11ms/step
# Epoch 15/1000
# 4/4 - 0s - loss: 0.6050 - val_loss: 0.5593 - 64ms/epoch - 16ms/step
# Epoch 16/1000
# 4/4 - 0s - loss: 0.5880 - val_loss: 0.5420 - 65ms/epoch - 16ms/step
# Epoch 17/1000
# 4/4 - 0s - loss: 0.5722 - val_loss: 0.5263 - 62ms/epoch - 15ms/step
# Epoch 18/1000
# 4/4 - 0s - loss: 0.5580 - val_loss: 0.5109 - 45ms/epoch - 11ms/step
# Epoch 19/1000
# 4/4 - 0s - loss: 0.5448 - val_loss: 0.4951 - 45ms/epoch - 11ms/step
# Epoch 20/1000
# 4/4 - 0s - loss: 0.5304 - val_loss: 0.4814 - 48ms/epoch - 12ms/step
# Epoch 21/1000
# 4/4 - 0s - loss: 0.5179 - val_loss: 0.4695 - 46ms/epoch - 11ms/step
# Epoch 22/1000
# 4/4 - 0s - loss: 0.5066 - val_loss: 0.4581 - 42ms/epoch - 11ms/step
# Epoch 23/1000
# 4/4 - 0s - loss: 0.4950 - val_loss: 0.4471 - 51ms/epoch - 13ms/step
# Epoch 24/1000
# 4/4 - 0s - loss: 0.4844 - val_loss: 0.4357 - 45ms/epoch - 11ms/step
# Epoch 25/1000
# 4/4 - 0s - loss: 0.4736 - val_loss: 0.4247 - 42ms/epoch - 10ms/step
# Epoch 26/1000
# 4/4 - 0s - loss: 0.4638 - val_loss: 0.4145 - 46ms/epoch - 12ms/step
# Epoch 27/1000
# 4/4 - 0s - loss: 0.4563 - val_loss: 0.4052 - 56ms/epoch - 14ms/step
# Epoch 28/1000
# 4/4 - 0s - loss: 0.4459 - val_loss: 0.3957 - 65ms/epoch - 16ms/step
# Epoch 29/1000
# 4/4 - 0s - loss: 0.4368 - val_loss: 0.3873 - 60ms/epoch - 15ms/step
# Epoch 30/1000
# 4/4 - 0s - loss: 0.4287 - val_loss: 0.3802 - 46ms/epoch - 11ms/step
# Epoch 31/1000
# 4/4 - 0s - loss: 0.4209 - val_loss: 0.3727 - 44ms/epoch - 11ms/step
# Epoch 32/1000
# 4/4 - 0s - loss: 0.4142 - val_loss: 0.3646 - 62ms/epoch - 16ms/step
# Epoch 33/1000
# 4/4 - 0s - loss: 0.4059 - val_loss: 0.3580 - 43ms/epoch - 11ms/step
# Epoch 34/1000
# 4/4 - 0s - loss: 0.3980 - val_loss: 0.3500 - 39ms/epoch - 10ms/step
# Epoch 35/1000
# 4/4 - 0s - loss: 0.3919 - val_loss: 0.3424 - 40ms/epoch - 10ms/step
# Epoch 36/1000
# 4/4 - 0s - loss: 0.3834 - val_loss: 0.3351 - 59ms/epoch - 15ms/step
# Epoch 37/1000
# 4/4 - 0s - loss: 0.3753 - val_loss: 0.3266 - 45ms/epoch - 11ms/step
# Epoch 38/1000
# 4/4 - 0s - loss: 0.3656 - val_loss: 0.3173 - 65ms/epoch - 16ms/step
# Epoch 39/1000
# 4/4 - 0s - loss: 0.3571 - val_loss: 0.3099 - 63ms/epoch - 16ms/step
# Epoch 40/1000
# 4/4 - 0s - loss: 0.3474 - val_loss: 0.2994 - 45ms/epoch - 11ms/step
# Epoch 41/1000
# 4/4 - 0s - loss: 0.3363 - val_loss: 0.2903 - 61ms/epoch - 15ms/step
# Epoch 42/1000
# 4/4 - 0s - loss: 0.3274 - val_loss: 0.2824 - 53ms/epoch - 13ms/step
# Epoch 43/1000
# 4/4 - 0s - loss: 0.3204 - val_loss: 0.2748 - 51ms/epoch - 13ms/step
# Epoch 44/1000
# 4/4 - 0s - loss: 0.3108 - val_loss: 0.2674 - 62ms/epoch - 16ms/step
# Epoch 45/1000
# 4/4 - 0s - loss: 0.3032 - val_loss: 0.2619 - 49ms/epoch - 12ms/step
# Epoch 46/1000
# 4/4 - 0s - loss: 0.2926 - val_loss: 0.2523 - 45ms/epoch - 11ms/step
# Epoch 47/1000
# 4/4 - 0s - loss: 0.2879 - val_loss: 0.2459 - 50ms/epoch - 12ms/step
# Epoch 48/1000
# 4/4 - 0s - loss: 0.2790 - val_loss: 0.2381 - 45ms/epoch - 11ms/step
# Epoch 49/1000
# 4/4 - 0s - loss: 0.2693 - val_loss: 0.2339 - 72ms/epoch - 18ms/step
# Epoch 50/1000
# 4/4 - 0s - loss: 0.2633 - val_loss: 0.2283 - 72ms/epoch - 18ms/step
# Epoch 51/1000
# 4/4 - 0s - loss: 0.2565 - val_loss: 0.2192 - 66ms/epoch - 17ms/step
# Epoch 52/1000
# 4/4 - 0s - loss: 0.2488 - val_loss: 0.2132 - 76ms/epoch - 19ms/step
# Epoch 53/1000
# 4/4 - 0s - loss: 0.2436 - val_loss: 0.2072 - 69ms/epoch - 17ms/step
# Epoch 54/1000
# 4/4 - 0s - loss: 0.2365 - val_loss: 0.2017 - 62ms/epoch - 15ms/step
# Epoch 55/1000
# 4/4 - 0s - loss: 0.2287 - val_loss: 0.1987 - 56ms/epoch - 14ms/step
# Epoch 56/1000
# 4/4 - 0s - loss: 0.2274 - val_loss: 0.1994 - 43ms/epoch - 11ms/step
# Epoch 57/1000
# 4/4 - 0s - loss: 0.2212 - val_loss: 0.1859 - 62ms/epoch - 16ms/step
# Epoch 58/1000
# 4/4 - 0s - loss: 0.2109 - val_loss: 0.1807 - 49ms/epoch - 12ms/step
# Epoch 59/1000
# 4/4 - 0s - loss: 0.2065 - val_loss: 0.1760 - 63ms/epoch - 16ms/step
# Epoch 60/1000
# 4/4 - 0s - loss: 0.2005 - val_loss: 0.1722 - 44ms/epoch - 11ms/step
# Epoch 61/1000
# 4/4 - 0s - loss: 0.1948 - val_loss: 0.1693 - 63ms/epoch - 16ms/step
# Epoch 62/1000
# 4/4 - 0s - loss: 0.1909 - val_loss: 0.1667 - 65ms/epoch - 16ms/step
# Epoch 63/1000
# 4/4 - 0s - loss: 0.1900 - val_loss: 0.1676 - 44ms/epoch - 11ms/step
# Epoch 64/1000
# 4/4 - 0s - loss: 0.1834 - val_loss: 0.1569 - 50ms/epoch - 13ms/step
# Epoch 65/1000
# 4/4 - 0s - loss: 0.1767 - val_loss: 0.1522 - 61ms/epoch - 15ms/step
# Epoch 66/1000
# 4/4 - 0s - loss: 0.1747 - val_loss: 0.1487 - 49ms/epoch - 12ms/step
# Epoch 67/1000
# 4/4 - 0s - loss: 0.1705 - val_loss: 0.1507 - 80ms/epoch - 20ms/step
# Epoch 68/1000
# 4/4 - 0s - loss: 0.1669 - val_loss: 0.1458 - 60ms/epoch - 15ms/step
# Epoch 69/1000
# 4/4 - 0s - loss: 0.1621 - val_loss: 0.1398 - 69ms/epoch - 17ms/step
# Epoch 70/1000
# 4/4 - 0s - loss: 0.1586 - val_loss: 0.1357 - 85ms/epoch - 21ms/step
# Epoch 71/1000
# 4/4 - 0s - loss: 0.1586 - val_loss: 0.1328 - 57ms/epoch - 14ms/step
# Epoch 72/1000
# 4/4 - 0s - loss: 0.1538 - val_loss: 0.1327 - 52ms/epoch - 13ms/step
# Epoch 73/1000
# 4/4 - 0s - loss: 0.1506 - val_loss: 0.1323 - 70ms/epoch - 18ms/step
# Epoch 74/1000
# 4/4 - 0s - loss: 0.1474 - val_loss: 0.1262 - 76ms/epoch - 19ms/step
# Epoch 75/1000
# 4/4 - 0s - loss: 0.1459 - val_loss: 0.1233 - 53ms/epoch - 13ms/step
# Epoch 76/1000
# 4/4 - 0s - loss: 0.1429 - val_loss: 0.1225 - 45ms/epoch - 11ms/step
# Epoch 77/1000
# 4/4 - 0s - loss: 0.1396 - val_loss: 0.1204 - 52ms/epoch - 13ms/step
# Epoch 78/1000
# 4/4 - 0s - loss: 0.1376 - val_loss: 0.1178 - 69ms/epoch - 17ms/step
# Epoch 79/1000
# 4/4 - 0s - loss: 0.1362 - val_loss: 0.1169 - 50ms/epoch - 12ms/step
# Epoch 80/1000
# 4/4 - 0s - loss: 0.1336 - val_loss: 0.1126 - 66ms/epoch - 16ms/step
# Epoch 81/1000
# 4/4 - 0s - loss: 0.1323 - val_loss: 0.1116 - 54ms/epoch - 14ms/step
# Epoch 82/1000
# 4/4 - 0s - loss: 0.1297 - val_loss: 0.1174 - 44ms/epoch - 11ms/step
# Epoch 83/1000
# 4/4 - 0s - loss: 0.1318 - val_loss: 0.1104 - 60ms/epoch - 15ms/step
# Epoch 84/1000
# 4/4 - 0s - loss: 0.1274 - val_loss: 0.1129 - 44ms/epoch - 11ms/step
# Epoch 85/1000
# 4/4 - 0s - loss: 0.1242 - val_loss: 0.1073 - 64ms/epoch - 16ms/step
# Epoch 86/1000
# 4/4 - 0s - loss: 0.1220 - val_loss: 0.1039 - 58ms/epoch - 15ms/step
# Epoch 87/1000
# 4/4 - 0s - loss: 0.1218 - val_loss: 0.1029 - 70ms/epoch - 17ms/step
# Epoch 88/1000
# 4/4 - 0s - loss: 0.1196 - val_loss: 0.1008 - 39ms/epoch - 10ms/step
# Epoch 89/1000
# 4/4 - 0s - loss: 0.1223 - val_loss: 0.0983 - 41ms/epoch - 10ms/step
# Epoch 90/1000
# 4/4 - 0s - loss: 0.1189 - val_loss: 0.1054 - 41ms/epoch - 10ms/step
# Epoch 91/1000
# 4/4 - 0s - loss: 0.1160 - val_loss: 0.1017 - 39ms/epoch - 10ms/step
# Epoch 92/1000
# 4/4 - 0s - loss: 0.1139 - val_loss: 0.0978 - 37ms/epoch - 9ms/step
# Epoch 93/1000
# 4/4 - 0s - loss: 0.1179 - val_loss: 0.0937 - 56ms/epoch - 14ms/step
# Epoch 94/1000
# 4/4 - 0s - loss: 0.1124 - val_loss: 0.0995 - 56ms/epoch - 14ms/step
# Epoch 95/1000
# 4/4 - 0s - loss: 0.1111 - val_loss: 0.0985 - 56ms/epoch - 14ms/step
# Epoch 96/1000
# 4/4 - 0s - loss: 0.1091 - val_loss: 0.0924 - 42ms/epoch - 11ms/step
# Epoch 97/1000
# 4/4 - 0s - loss: 0.1083 - val_loss: 0.0902 - 40ms/epoch - 10ms/step
# Epoch 98/1000
# 4/4 - 0s - loss: 0.1081 - val_loss: 0.0890 - 38ms/epoch - 10ms/step
# Epoch 99/1000
# 4/4 - 0s - loss: 0.1067 - val_loss: 0.0902 - 38ms/epoch - 9ms/step
# Epoch 100/1000
# 4/4 - 0s - loss: 0.1052 - val_loss: 0.0905 - 59ms/epoch - 15ms/step
# Epoch 101/1000
# 4/4 - 0s - loss: 0.1050 - val_loss: 0.0890 - 40ms/epoch - 10ms/step
# Epoch 102/1000
# 4/4 - 0s - loss: 0.1032 - val_loss: 0.0899 - 43ms/epoch - 11ms/step
# Epoch 103/1000
# 4/4 - 0s - loss: 0.1026 - val_loss: 0.0874 - 53ms/epoch - 13ms/step
# Epoch 104/1000
# 4/4 - 0s - loss: 0.1021 - val_loss: 0.0852 - 49ms/epoch - 12ms/step
# Epoch 105/1000
# 4/4 - 0s - loss: 0.1018 - val_loss: 0.0846 - 60ms/epoch - 15ms/step
# Epoch 106/1000
# 4/4 - 0s - loss: 0.1006 - val_loss: 0.0872 - 42ms/epoch - 11ms/step
# Epoch 107/1000
# 4/4 - 0s - loss: 0.0997 - val_loss: 0.0821 - 57ms/epoch - 14ms/step
# Epoch 108/1000
# 4/4 - 0s - loss: 0.1004 - val_loss: 0.0810 - 60ms/epoch - 15ms/step
# Epoch 109/1000
# 4/4 - 0s - loss: 0.0992 - val_loss: 0.0902 - 42ms/epoch - 10ms/step
# Epoch 110/1000
# 4/4 - 0s - loss: 0.0978 - val_loss: 0.0831 - 60ms/epoch - 15ms/step
# Epoch 111/1000
# 4/4 - 0s - loss: 0.0964 - val_loss: 0.0785 - 62ms/epoch - 16ms/step
# Epoch 112/1000
# 4/4 - 0s - loss: 0.0958 - val_loss: 0.0778 - 56ms/epoch - 14ms/step
# Epoch 113/1000
# 4/4 - 0s - loss: 0.0962 - val_loss: 0.0783 - 41ms/epoch - 10ms/step
# Epoch 114/1000
# 4/4 - 0s - loss: 0.0943 - val_loss: 0.0845 - 57ms/epoch - 14ms/step
# Epoch 115/1000
# 4/4 - 0s - loss: 0.0943 - val_loss: 0.0844 - 45ms/epoch - 11ms/step
# Epoch 116/1000
# Restoring model weights from the end of the best epoch: 111.
# 4/4 - 0s - loss: 0.0946 - val_loss: 0.0777 - 70ms/epoch - 17ms/step
# Epoch 116: early stopping

# %% [markdown]
# There are a number of parameters that are specified to the **EarlyStopping** object.
#
# * **min_delta** This value should be kept small. It simply means the minimum change in error to be registered as an improvement.  Setting it even smaller will not likely have a great deal of impact.
# * **patience** How long should the training wait for the validation error to improve?
# * **verbose** How much progress information do you want?
# * **mode** In general, always set this to "auto".  This allows you to specify if the error should be minimized or maximized.  Consider accuracy, where higher numbers are desired vs log-loss/RMSE where lower numbers are desired.
# * **restore_best_weights** This should always be set to true.  This restores the weights to the values they were at when the validation set is the highest.  Unless you are manually tracking the weights yourself (we do not use this technique in this course), you should have Keras perform this step for you.
#
# As you can see from above, the entire number of requested epochs were not used.  The neural network training stopped once the validation set no longer improved.

# %%
from sklearn.metrics import accuracy_score

pred = model.predict(x_test)
predict_classes = np.argmax(pred,axis=1)
expected_classes = np.argmax(y_test,axis=1)
correct = accuracy_score(expected_classes,predict_classes)
print(f"Accuracy: {correct}")
# Out:
# 2/2 [==============================] - 0s 7ms/step
# Accuracy: 1.0

# %% [markdown]
# ## Early Stopping with Regression
#
# The following code demonstrates how we can apply early stopping to a regression problem.  The technique is similar to the early stopping for classification code that we just saw.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])

cars = df['name']

# Handle missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

# Split into validation and training sets
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')

monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
        patience=5, verbose=1, mode='auto',
        restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor], verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 10/10 - 1s - loss: 401969.8125 - val_loss: 230023.1562 - 1s/epoch - 119ms/step
# Epoch 2/1000
# 10/10 - 0s - loss: 155540.3438 - val_loss: 71905.7031 - 60ms/epoch - 6ms/step
# Epoch 3/1000
# 10/10 - 0s - loss: 41697.6367 - val_loss: 12935.9375 - 92ms/epoch - 9ms/step
# Epoch 4/1000
# 10/10 - 0s - loss: 6111.1377 - val_loss: 498.9060 - 61ms/epoch - 6ms/step
# Epoch 5/1000
# 10/10 - 0s - loss: 301.8080 - val_loss: 757.7764 - 73ms/epoch - 7ms/step
# Epoch 6/1000
# 10/10 - 0s - loss: 970.1966 - val_loss: 1110.5300 - 67ms/epoch - 7ms/step
# Epoch 7/1000
# 10/10 - 0s - loss: 784.2480 - val_loss: 471.0345 - 62ms/epoch - 6ms/step
# Epoch 8/1000
# 10/10 - 0s - loss: 262.1138 - val_loss: 139.3321 - 69ms/epoch - 7ms/step
# Epoch 9/1000
# 10/10 - 0s - loss: 131.1034 - val_loss: 116.2123 - 80ms/epoch - 8ms/step
# Epoch 10/1000
# 10/10 - 0s - loss: 150.8296 - val_loss: 118.6225 - 73ms/epoch - 7ms/step
# Epoch 11/1000
# 10/10 - 0s - loss: 140.3909 - val_loss: 111.9273 - 58ms/epoch - 6ms/step
# Epoch 12/1000
# 10/10 - 0s - loss: 130.3715 - val_loss: 116.7702 - 67ms/epoch - 7ms/step
# Epoch 13/1000
# 10/10 - 0s - loss: 129.7399 - val_loss: 119.6309 - 70ms/epoch - 7ms/step
# Epoch 14/1000
# 10/10 - 0s - loss: 129.4090 - val_loss: 117.3850 - 63ms/epoch - 6ms/step
# Epoch 15/1000
# 10/10 - 0s - loss: 128.5160 - val_loss: 115.1762 - 71ms/epoch - 7ms/step
# Epoch 16/1000
# Restoring model weights from the end of the best epoch: 11.
# 10/10 - 0s - loss: 128.1475 - val_loss: 114.2502 - 69ms/epoch - 7ms/step
# Epoch 16: early stopping

# %% [markdown]
# Finally, we evaluate the error.

# %%
# Measure RMSE error.  RMSE is common for regression.
pred = model.predict(x_test)
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print(f"Final score (RMSE): {score}")
# Out:
# 4/4 [==============================] - 0s 4ms/step
# Final score (RMSE): 10.579575263847552
