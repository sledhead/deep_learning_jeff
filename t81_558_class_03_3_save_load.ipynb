# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_3_save_load.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 3: Introduction to TensorFlow**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 3 Material
#
# * Part 3.1: Deep Learning and Neural Network Introduction [[Video]](https://www.youtube.com/watch?v=zYnI4iWRmpc&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_1_neural_net.ipynb)
# * Part 3.2: Introduction to Tensorflow and Keras [[Video]](https://www.youtube.com/watch?v=PsE73jk55cE&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_2_keras.ipynb)
# * **Part 3.3: Saving and Loading a Keras Neural Network** [[Video]](https://www.youtube.com/watch?v=-9QfbGM1qGw&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_3_save_load.ipynb)
# * Part 3.4: Early Stopping in Keras to Prevent Overfitting [[Video]](https://www.youtube.com/watch?v=m1LNunuI2fk&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_4_early_stop.ipynb)
# * Part 3.5: Extracting Weights and Manual Calculation [[Video]](https://www.youtube.com/watch?v=7PWgx16kH8s&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_03_5_weights.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.
#   Running the following code will map your GDrive to ```/content/drive```.

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    COLAB = True
    print("Note: using Google CoLab")
    # %tensorflow_version 2.x
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Mounted at /content/drive
# Note: using Google CoLab
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %% [markdown]
# # Part 3.3: Saving and Loading a Keras Neural Network
#
# Complex neural networks will take a long time to fit/train.  It is helpful to be able to save these neural networks so that you can reload them later.  A reloaded neural network will not require retraining.  Keras provides three formats for neural network saving.
#
# * **JSON** - Stores the neural network structure (no weights) in the [JSON file format](https://en.wikipedia.org/wiki/JSON).
# * **HDF5** - Stores the complete neural network (with weights) in the [HDF5 file format](https://en.wikipedia.org/wiki/Hierarchical_Data_Format). Do not confuse HDF5 with [HDFS](https://en.wikipedia.org/wiki/Apache_Hadoop).  They are different.  We do not use HDFS in this class.
#
# Usually, you will want to save in HDF5.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import pandas as pd
import io
import os
import requests
import numpy as np
from sklearn import metrics

save_path = "."

df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/auto-mpg.csv", 
    na_values=['NA', '?'])

cars = df['name']

# Handle missing value
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].median())

# Pandas to Numpy
x = df[['cylinders', 'displacement', 'horsepower', 'weight',
       'acceleration', 'year', 'origin']].values
y = df['mpg'].values # regression

# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x,y,verbose=2,epochs=100)

# Predict
pred = model.predict(x)

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y))
print(f"Before save score (RMSE): {score}")

# save neural network structure to JSON (no weights)
model_json = model.to_json()
with open(os.path.join(save_path,"network.json"), "w") as json_file:
    json_file.write(model_json)

# save entire network to HDF5 (save everything, suggested)
model.save(os.path.join(save_path,"network.h5"))
# Out:
# Epoch 1/100
# 13/13 - 1s - loss: 1888797.8750 - 1s/epoch - 81ms/step
# Epoch 2/100
# 13/13 - 0s - loss: 1064819.0000 - 36ms/epoch - 3ms/step
# Epoch 3/100
# 13/13 - 0s - loss: 557686.5625 - 31ms/epoch - 2ms/step
# Epoch 4/100
# 13/13 - 0s - loss: 285525.5000 - 30ms/epoch - 2ms/step
# Epoch 5/100
# 13/13 - 0s - loss: 151456.4062 - 28ms/epoch - 2ms/step
# Epoch 6/100
# 13/13 - 0s - loss: 73523.6094 - 42ms/epoch - 3ms/step
# Epoch 7/100
# 13/13 - 0s - loss: 32929.0664 - 41ms/epoch - 3ms/step
# Epoch 8/100
# 13/13 - 0s - loss: 13427.4473 - 35ms/epoch - 3ms/step
# Epoch 9/100
# 13/13 - 0s - loss: 5105.5933 - 38ms/epoch - 3ms/step
# Epoch 10/100
# 13/13 - 0s - loss: 2037.3250 - 36ms/epoch - 3ms/step
# Epoch 11/100
# 13/13 - 0s - loss: 1053.1948 - 28ms/epoch - 2ms/step
# Epoch 12/100
# 13/13 - 0s - loss: 827.3114 - 32ms/epoch - 2ms/step
# Epoch 13/100
# 13/13 - 0s - loss: 774.1371 - 29ms/epoch - 2ms/step
# Epoch 14/100
# 13/13 - 0s - loss: 767.9988 - 33ms/epoch - 3ms/step
# Epoch 15/100
# 13/13 - 0s - loss: 765.3188 - 41ms/epoch - 3ms/step
# Epoch 16/100
# 13/13 - 0s - loss: 762.7377 - 32ms/epoch - 2ms/step
# Epoch 17/100
# 13/13 - 0s - loss: 760.1578 - 28ms/epoch - 2ms/step
# Epoch 18/100
# 13/13 - 0s - loss: 757.9224 - 34ms/epoch - 3ms/step
# Epoch 19/100
# 13/13 - 0s - loss: 755.1390 - 34ms/epoch - 3ms/step
# Epoch 20/100
# 13/13 - 0s - loss: 752.5771 - 29ms/epoch - 2ms/step
# Epoch 21/100
# 13/13 - 0s - loss: 750.1023 - 32ms/epoch - 2ms/step
# Epoch 22/100
# 13/13 - 0s - loss: 747.8232 - 28ms/epoch - 2ms/step
# Epoch 23/100
# 13/13 - 0s - loss: 744.8364 - 34ms/epoch - 3ms/step
# Epoch 24/100
# 13/13 - 0s - loss: 741.8790 - 30ms/epoch - 2ms/step
# Epoch 25/100
# 13/13 - 0s - loss: 739.1480 - 31ms/epoch - 2ms/step
# Epoch 26/100
# 13/13 - 0s - loss: 736.7701 - 25ms/epoch - 2ms/step
# Epoch 27/100
# 13/13 - 0s - loss: 733.5812 - 29ms/epoch - 2ms/step
# Epoch 28/100
# 13/13 - 0s - loss: 731.2385 - 29ms/epoch - 2ms/step
# Epoch 29/100
# 13/13 - 0s - loss: 728.0522 - 27ms/epoch - 2ms/step
# Epoch 30/100
# 13/13 - 0s - loss: 724.4515 - 29ms/epoch - 2ms/step
# Epoch 31/100
# 13/13 - 0s - loss: 721.6666 - 34ms/epoch - 3ms/step
# Epoch 32/100
# 13/13 - 0s - loss: 719.0500 - 38ms/epoch - 3ms/step
# Epoch 33/100
# 13/13 - 0s - loss: 715.4709 - 30ms/epoch - 2ms/step
# Epoch 34/100
# 13/13 - 0s - loss: 712.0970 - 37ms/epoch - 3ms/step
# Epoch 35/100
# 13/13 - 0s - loss: 708.7613 - 26ms/epoch - 2ms/step
# Epoch 36/100
# 13/13 - 0s - loss: 705.9559 - 31ms/epoch - 2ms/step
# Epoch 37/100
# 13/13 - 0s - loss: 702.5208 - 27ms/epoch - 2ms/step
# Epoch 38/100
# 13/13 - 0s - loss: 699.7639 - 29ms/epoch - 2ms/step
# Epoch 39/100
# 13/13 - 0s - loss: 696.8973 - 27ms/epoch - 2ms/step
# Epoch 40/100
# 13/13 - 0s - loss: 693.5175 - 26ms/epoch - 2ms/step
# Epoch 41/100
# 13/13 - 0s - loss: 689.4088 - 28ms/epoch - 2ms/step
# Epoch 42/100
# 13/13 - 0s - loss: 686.1485 - 28ms/epoch - 2ms/step
# Epoch 43/100
# 13/13 - 0s - loss: 682.0173 - 31ms/epoch - 2ms/step
# Epoch 44/100
# 13/13 - 0s - loss: 678.7832 - 27ms/epoch - 2ms/step
# Epoch 45/100
# 13/13 - 0s - loss: 675.5156 - 28ms/epoch - 2ms/step
# Epoch 46/100
# 13/13 - 0s - loss: 671.9567 - 30ms/epoch - 2ms/step
# Epoch 47/100
# 13/13 - 0s - loss: 667.8336 - 31ms/epoch - 2ms/step
# Epoch 48/100
# 13/13 - 0s - loss: 665.2112 - 29ms/epoch - 2ms/step
# Epoch 49/100
# 13/13 - 0s - loss: 661.1268 - 27ms/epoch - 2ms/step
# Epoch 50/100
# 13/13 - 0s - loss: 657.6693 - 26ms/epoch - 2ms/step
# Epoch 51/100
# 13/13 - 0s - loss: 653.9641 - 27ms/epoch - 2ms/step
# Epoch 52/100
# 13/13 - 0s - loss: 650.1942 - 45ms/epoch - 3ms/step
# Epoch 53/100
# 13/13 - 0s - loss: 646.1893 - 35ms/epoch - 3ms/step
# Epoch 54/100
# 13/13 - 0s - loss: 642.4945 - 28ms/epoch - 2ms/step
# Epoch 55/100
# 13/13 - 0s - loss: 639.3932 - 30ms/epoch - 2ms/step
# Epoch 56/100
# 13/13 - 0s - loss: 635.7339 - 28ms/epoch - 2ms/step
# Epoch 57/100
# 13/13 - 0s - loss: 631.1082 - 32ms/epoch - 2ms/step
# Epoch 58/100
# 13/13 - 0s - loss: 627.7404 - 33ms/epoch - 3ms/step
# Epoch 59/100
# 13/13 - 0s - loss: 623.2404 - 27ms/epoch - 2ms/step
# Epoch 60/100
# 13/13 - 0s - loss: 619.3036 - 36ms/epoch - 3ms/step
# Epoch 61/100
# 13/13 - 0s - loss: 615.8407 - 34ms/epoch - 3ms/step
# Epoch 62/100
# 13/13 - 0s - loss: 611.4358 - 36ms/epoch - 3ms/step
# Epoch 63/100
# 13/13 - 0s - loss: 607.6547 - 33ms/epoch - 3ms/step
# Epoch 64/100
# 13/13 - 0s - loss: 603.3755 - 52ms/epoch - 4ms/step
# Epoch 65/100
# 13/13 - 0s - loss: 600.2266 - 45ms/epoch - 3ms/step
# Epoch 66/100
# 13/13 - 0s - loss: 595.5389 - 29ms/epoch - 2ms/step
# Epoch 67/100
# 13/13 - 0s - loss: 592.4183 - 28ms/epoch - 2ms/step
# Epoch 68/100
# 13/13 - 0s - loss: 587.5230 - 29ms/epoch - 2ms/step
# Epoch 69/100
# 13/13 - 0s - loss: 585.2851 - 36ms/epoch - 3ms/step
# Epoch 70/100
# 13/13 - 0s - loss: 581.5080 - 31ms/epoch - 2ms/step
# Epoch 71/100
# 13/13 - 0s - loss: 575.4139 - 29ms/epoch - 2ms/step
# Epoch 72/100
# 13/13 - 0s - loss: 571.2628 - 34ms/epoch - 3ms/step
# Epoch 73/100
# 13/13 - 0s - loss: 567.7372 - 37ms/epoch - 3ms/step
# Epoch 74/100
# 13/13 - 0s - loss: 563.6804 - 36ms/epoch - 3ms/step
# Epoch 75/100
# 13/13 - 0s - loss: 562.5859 - 54ms/epoch - 4ms/step
# Epoch 76/100
# 13/13 - 0s - loss: 555.5731 - 28ms/epoch - 2ms/step
# Epoch 77/100
# 13/13 - 0s - loss: 551.5398 - 28ms/epoch - 2ms/step
# Epoch 78/100
# 13/13 - 0s - loss: 547.3463 - 27ms/epoch - 2ms/step
# Epoch 79/100
# 13/13 - 0s - loss: 543.2687 - 35ms/epoch - 3ms/step
# Epoch 80/100
# 13/13 - 0s - loss: 540.0453 - 27ms/epoch - 2ms/step
# Epoch 81/100
# 13/13 - 0s - loss: 534.6739 - 27ms/epoch - 2ms/step
# Epoch 82/100
# 13/13 - 0s - loss: 530.5739 - 32ms/epoch - 2ms/step
# Epoch 83/100
# 13/13 - 0s - loss: 526.8300 - 37ms/epoch - 3ms/step
# Epoch 84/100
# 13/13 - 0s - loss: 522.8338 - 29ms/epoch - 2ms/step
# Epoch 85/100
# 13/13 - 0s - loss: 522.4041 - 30ms/epoch - 2ms/step
# Epoch 86/100
# 13/13 - 0s - loss: 514.8440 - 37ms/epoch - 3ms/step
# Epoch 87/100
# 13/13 - 0s - loss: 511.6891 - 34ms/epoch - 3ms/step
# Epoch 88/100
# 13/13 - 0s - loss: 506.1647 - 27ms/epoch - 2ms/step
# Epoch 89/100
# 13/13 - 0s - loss: 502.4245 - 27ms/epoch - 2ms/step
# Epoch 90/100
# 13/13 - 0s - loss: 497.9781 - 30ms/epoch - 2ms/step
# Epoch 91/100
# 13/13 - 0s - loss: 493.5909 - 32ms/epoch - 2ms/step
# Epoch 92/100
# 13/13 - 0s - loss: 490.5478 - 45ms/epoch - 3ms/step
# Epoch 93/100
# 13/13 - 0s - loss: 485.1374 - 31ms/epoch - 2ms/step
# Epoch 94/100
# 13/13 - 0s - loss: 481.8011 - 33ms/epoch - 3ms/step
# Epoch 95/100
# 13/13 - 0s - loss: 477.2785 - 34ms/epoch - 3ms/step
# Epoch 96/100
# 13/13 - 0s - loss: 473.9500 - 29ms/epoch - 2ms/step
# Epoch 97/100
# 13/13 - 0s - loss: 469.4966 - 30ms/epoch - 2ms/step
# Epoch 98/100
# 13/13 - 0s - loss: 465.0231 - 29ms/epoch - 2ms/step
# Epoch 99/100
# 13/13 - 0s - loss: 460.7391 - 26ms/epoch - 2ms/step
# Epoch 100/100
# 13/13 - 0s - loss: 456.7647 - 28ms/epoch - 2ms/step
# 13/13 [==============================] - 0s 2ms/step
# Before save score (RMSE): 21.309187784369634

# %% [markdown]
# The code below sets up a neural network and reads the data (for predictions), but it does not clear the model directory or fit the neural network. The code loads the weights from the previous fit. Now we reload the network and perform another prediction. The RMSE should match the previous one exactly if we saved and reloaded the neural network correctly.

# %%
from tensorflow.keras.models import load_model
model2 = load_model(os.path.join(save_path,"network.h5"))
pred = model2.predict(x)
# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y))
print(f"After load score (RMSE): {score}")
# Out:
# 13/13 [==============================] - 0s 2ms/step
# After load score (RMSE): 21.309187784369634
