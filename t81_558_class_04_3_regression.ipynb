# %% [markdown]
# <a href="https://colab.research.google.com/github/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_04_3_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # T81-558: Applications of Deep Neural Networks
# **Module 4: Training for Tabular Data**
# * Instructor: [Jeff Heaton](https://sites.wustl.edu/jeffheaton/), McKelvey School of Engineering, [Washington University in St. Louis](https://engineering.wustl.edu/Programs/Pages/default.aspx)
# * For more information visit the [class website](https://sites.wustl.edu/jeffheaton/t81-558/).

# %% [markdown]
# # Module 4 Material
#
# * Part 4.1: Encoding a Feature Vector for Keras Deep Learning [[Video]](https://www.youtube.com/watch?v=Vxz-gfs9nMQ&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_04_1_feature_encode.ipynb)
# * Part 4.2: Keras Multiclass Classification for Deep Neural Networks with ROC and AUC [[Video]](https://www.youtube.com/watch?v=-f3bg9dLMks&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_04_2_multi_class.ipynb)
# * **Part 4.3: Keras Regression for Deep Neural Networks with RMSE** [[Video]](https://www.youtube.com/watch?v=wNhBUC6X5-E&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_04_3_regression.ipynb)
# * Part 4.4: Backpropagation, Nesterov Momentum, and ADAM Neural Network Training [[Video]](https://www.youtube.com/watch?v=VbDg8aBgpck&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_04_4_backprop.ipynb)
# * Part 4.5: Neural Network RMSE and Log Loss Error Calculation from Scratch [[Video]](https://www.youtube.com/watch?v=wmQX1t2PHJc&list=PLjy4p-07OYzulelvJ5KVaT2pDlxivl_BN) [[Notebook]](https://github.com/jeffheaton/t81_558_deep_learning/blob/master/t81_558_class_04_5_rmse_logloss.ipynb)

# %% [markdown]
# # Google CoLab Instructions
#
# The following code ensures that Google CoLab is running the correct version of TensorFlow.

# %%
try:
    # %tensorflow_version 2.x
    COLAB = True
    print("Note: using Google CoLab")
except:
    print("Note: not using Google CoLab")
    COLAB = False
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.
# Note: using Google CoLab

# %% [markdown]
# # Part 4.3: Keras Regression for Deep Neural Networks with RMSE
#
# We evaluate regression results differently than classification.  Consider the following code that trains a neural network for regression on the data set **jh-simple-dataset.csv**.  We begin by preparing the data set.

# %%
import pandas as pd
from scipy.stats import zscore
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Read the data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/jh-simple-dataset.csv",
    na_values=['NA','?'])

# Generate dummies for job
df = pd.concat([df,pd.get_dummies(df['job'],prefix="job")],axis=1)
df.drop('job', axis=1, inplace=True)

# Generate dummies for area
df = pd.concat([df,pd.get_dummies(df['area'],prefix="area")],axis=1)
df.drop('area', axis=1, inplace=True)

# Generate dummies for product
df = pd.concat([df,pd.get_dummies(df['product'],prefix="product")],axis=1)
df.drop('product', axis=1, inplace=True)

# Missing values for income
med = df['income'].median()
df['income'] = df['income'].fillna(med)

# Standardize ranges
df['income'] = zscore(df['income'])
df['aspect'] = zscore(df['aspect'])
df['save_rate'] = zscore(df['save_rate'])
df['subscriptions'] = zscore(df['subscriptions'])

# Convert to numpy - Classification
x_columns = df.columns.drop('age').drop('id')
x = df[x_columns].values
y = df['age'].values

# Create train/test
x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# %% [markdown]
# Next, we create a neural network to fit the data we just loaded.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

# Build the neural network
model = Sequential()
model.add(Dense(25, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(10, activation='relu')) # Hidden 2
model.add(Dense(1)) # Output
model.compile(loss='mean_squared_error', optimizer='adam')
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, 
                        patience=5, verbose=1, mode='auto', 
                        restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
          callbacks=[monitor],verbose=2,epochs=1000)
# Out:
# Epoch 1/1000
# 47/47 - 1s - loss: 2108.6318 - val_loss: 1855.1044 - 1s/epoch - 25ms/step
# Epoch 2/1000
# 47/47 - 0s - loss: 1690.2478 - val_loss: 1430.5985 - 110ms/epoch - 2ms/step
# Epoch 3/1000
# 47/47 - 0s - loss: 1161.9479 - val_loss: 811.1783 - 117ms/epoch - 2ms/step
# Epoch 4/1000
# 47/47 - 0s - loss: 564.2614 - val_loss: 349.2690 - 111ms/epoch - 2ms/step
# Epoch 5/1000
# 47/47 - 0s - loss: 294.9259 - val_loss: 254.4280 - 120ms/epoch - 3ms/step
# Epoch 6/1000
# 47/47 - 0s - loss: 247.8306 - val_loss: 230.1412 - 128ms/epoch - 3ms/step
# Epoch 7/1000
# 47/47 - 0s - loss: 222.9005 - val_loss: 207.3840 - 170ms/epoch - 4ms/step
# Epoch 8/1000
# 47/47 - 0s - loss: 198.9772 - val_loss: 185.6936 - 126ms/epoch - 3ms/step
# Epoch 9/1000
# 47/47 - 0s - loss: 176.3382 - val_loss: 164.1900 - 124ms/epoch - 3ms/step
# Epoch 10/1000
# 47/47 - 0s - loss: 154.7693 - val_loss: 144.7004 - 123ms/epoch - 3ms/step
# Epoch 11/1000
# 47/47 - 0s - loss: 135.1598 - val_loss: 126.1632 - 133ms/epoch - 3ms/step
# Epoch 12/1000
# 47/47 - 0s - loss: 117.2128 - val_loss: 110.7600 - 117ms/epoch - 2ms/step
# Epoch 13/1000
# 47/47 - 0s - loss: 101.6315 - val_loss: 96.1980 - 134ms/epoch - 3ms/step
# Epoch 14/1000
# 47/47 - 0s - loss: 87.9852 - val_loss: 84.5213 - 148ms/epoch - 3ms/step
# Epoch 15/1000
# 47/47 - 0s - loss: 76.5609 - val_loss: 73.9376 - 121ms/epoch - 3ms/step
# Epoch 16/1000
# 47/47 - 0s - loss: 66.9565 - val_loss: 65.4394 - 157ms/epoch - 3ms/step
# Epoch 17/1000
# 47/47 - 0s - loss: 58.7656 - val_loss: 58.2452 - 158ms/epoch - 3ms/step
# Epoch 18/1000
# 47/47 - 0s - loss: 51.9891 - val_loss: 52.0425 - 171ms/epoch - 4ms/step
# Epoch 19/1000
# 47/47 - 0s - loss: 45.2383 - val_loss: 45.8861 - 124ms/epoch - 3ms/step
# Epoch 20/1000
# 47/47 - 0s - loss: 39.4860 - val_loss: 40.9658 - 125ms/epoch - 3ms/step
# Epoch 21/1000
# 47/47 - 0s - loss: 35.0193 - val_loss: 37.1927 - 131ms/epoch - 3ms/step
# Epoch 22/1000
# 47/47 - 0s - loss: 31.3059 - val_loss: 33.5811 - 165ms/epoch - 4ms/step
# Epoch 23/1000
# 47/47 - 0s - loss: 28.0265 - val_loss: 30.6251 - 187ms/epoch - 4ms/step
# Epoch 24/1000
# 47/47 - 0s - loss: 25.4811 - val_loss: 27.8625 - 258ms/epoch - 5ms/step
# Epoch 25/1000
# 47/47 - 0s - loss: 23.0817 - val_loss: 25.6288 - 199ms/epoch - 4ms/step
# Epoch 26/1000
# 47/47 - 0s - loss: 21.2853 - val_loss: 23.5323 - 192ms/epoch - 4ms/step
# Epoch 27/1000
# 47/47 - 0s - loss: 19.4453 - val_loss: 21.7629 - 171ms/epoch - 4ms/step
# Epoch 28/1000
# 47/47 - 0s - loss: 18.1477 - val_loss: 20.2779 - 237ms/epoch - 5ms/step
# Epoch 29/1000
# 47/47 - 0s - loss: 16.9282 - val_loss: 19.0298 - 215ms/epoch - 5ms/step
# Epoch 30/1000
# 47/47 - 0s - loss: 15.8846 - val_loss: 17.9454 - 233ms/epoch - 5ms/step
# Epoch 31/1000
# 47/47 - 0s - loss: 15.1001 - val_loss: 17.0616 - 190ms/epoch - 4ms/step
# Epoch 32/1000
# 47/47 - 0s - loss: 14.4990 - val_loss: 16.1425 - 187ms/epoch - 4ms/step
# Epoch 33/1000
# 47/47 - 0s - loss: 13.8387 - val_loss: 15.4321 - 207ms/epoch - 4ms/step
# Epoch 34/1000
# 47/47 - 0s - loss: 13.2124 - val_loss: 14.8571 - 228ms/epoch - 5ms/step
# Epoch 35/1000
# 47/47 - 0s - loss: 12.7587 - val_loss: 14.2973 - 234ms/epoch - 5ms/step
# Epoch 36/1000
# 47/47 - 0s - loss: 12.4495 - val_loss: 13.8489 - 141ms/epoch - 3ms/step
# Epoch 37/1000
# 47/47 - 0s - loss: 12.0954 - val_loss: 13.5851 - 123ms/epoch - 3ms/step
# Epoch 38/1000
# 47/47 - 0s - loss: 11.7158 - val_loss: 12.9966 - 119ms/epoch - 3ms/step
# Epoch 39/1000
# 47/47 - 0s - loss: 11.4602 - val_loss: 12.5983 - 129ms/epoch - 3ms/step
# Epoch 40/1000
# 47/47 - 0s - loss: 11.1367 - val_loss: 12.3818 - 124ms/epoch - 3ms/step
# Epoch 41/1000
# 47/47 - 0s - loss: 10.8547 - val_loss: 12.0082 - 179ms/epoch - 4ms/step
# Epoch 42/1000
# 47/47 - 0s - loss: 10.5812 - val_loss: 11.8277 - 133ms/epoch - 3ms/step
# Epoch 43/1000
# 47/47 - 0s - loss: 10.3282 - val_loss: 11.3763 - 176ms/epoch - 4ms/step
# Epoch 44/1000
# 47/47 - 0s - loss: 10.0852 - val_loss: 11.7036 - 157ms/epoch - 3ms/step
# Epoch 45/1000
# 47/47 - 0s - loss: 9.9082 - val_loss: 11.3266 - 126ms/epoch - 3ms/step
# Epoch 46/1000
# 47/47 - 0s - loss: 9.7422 - val_loss: 10.8215 - 118ms/epoch - 3ms/step
# Epoch 47/1000
# 47/47 - 0s - loss: 9.4303 - val_loss: 10.4258 - 166ms/epoch - 4ms/step
# Epoch 48/1000
# 47/47 - 0s - loss: 9.2583 - val_loss: 10.1462 - 128ms/epoch - 3ms/step
# Epoch 49/1000
# 47/47 - 0s - loss: 9.0982 - val_loss: 9.8772 - 135ms/epoch - 3ms/step
# Epoch 50/1000
# 47/47 - 0s - loss: 8.8766 - val_loss: 9.8144 - 137ms/epoch - 3ms/step
# Epoch 51/1000
# 47/47 - 0s - loss: 8.7126 - val_loss: 9.7026 - 160ms/epoch - 3ms/step
# Epoch 52/1000
# 47/47 - 0s - loss: 8.5151 - val_loss: 9.3616 - 125ms/epoch - 3ms/step
# Epoch 53/1000
# 47/47 - 0s - loss: 8.2964 - val_loss: 9.2721 - 135ms/epoch - 3ms/step
# Epoch 54/1000
# 47/47 - 0s - loss: 8.0707 - val_loss: 8.8708 - 119ms/epoch - 3ms/step
# Epoch 55/1000
# 47/47 - 0s - loss: 7.9889 - val_loss: 8.6094 - 121ms/epoch - 3ms/step
# Epoch 56/1000
# 47/47 - 0s - loss: 7.7383 - val_loss: 8.5864 - 122ms/epoch - 3ms/step
# Epoch 57/1000
# 47/47 - 0s - loss: 7.5700 - val_loss: 8.3060 - 121ms/epoch - 3ms/step
# Epoch 58/1000
# 47/47 - 0s - loss: 7.4939 - val_loss: 8.3705 - 125ms/epoch - 3ms/step
# Epoch 59/1000
# 47/47 - 0s - loss: 7.2040 - val_loss: 7.8520 - 129ms/epoch - 3ms/step
# Epoch 60/1000
# 47/47 - 0s - loss: 7.0057 - val_loss: 7.8331 - 117ms/epoch - 2ms/step
# Epoch 61/1000
# 47/47 - 0s - loss: 6.8478 - val_loss: 8.0658 - 149ms/epoch - 3ms/step
# Epoch 62/1000
# 47/47 - 0s - loss: 6.7233 - val_loss: 7.7467 - 172ms/epoch - 4ms/step
# Epoch 63/1000
# 47/47 - 0s - loss: 6.4982 - val_loss: 7.0954 - 131ms/epoch - 3ms/step
# Epoch 64/1000
# 47/47 - 0s - loss: 6.3314 - val_loss: 6.9581 - 125ms/epoch - 3ms/step
# Epoch 65/1000
# 47/47 - 0s - loss: 6.2012 - val_loss: 6.7492 - 129ms/epoch - 3ms/step
# Epoch 66/1000
# 47/47 - 0s - loss: 6.0187 - val_loss: 6.5938 - 132ms/epoch - 3ms/step
# Epoch 67/1000
# 47/47 - 0s - loss: 5.8670 - val_loss: 6.4936 - 184ms/epoch - 4ms/step
# Epoch 68/1000
# 47/47 - 0s - loss: 5.7278 - val_loss: 6.2149 - 124ms/epoch - 3ms/step
# Epoch 69/1000
# 47/47 - 0s - loss: 5.5568 - val_loss: 6.2078 - 163ms/epoch - 3ms/step
# Epoch 70/1000
# 47/47 - 0s - loss: 5.4203 - val_loss: 5.8696 - 127ms/epoch - 3ms/step
# Epoch 71/1000
# 47/47 - 0s - loss: 5.2758 - val_loss: 5.7159 - 119ms/epoch - 3ms/step
# Epoch 72/1000
# 47/47 - 0s - loss: 5.0846 - val_loss: 5.7849 - 140ms/epoch - 3ms/step
# Epoch 73/1000
# 47/47 - 0s - loss: 4.9796 - val_loss: 5.4266 - 132ms/epoch - 3ms/step
# Epoch 74/1000
# 47/47 - 0s - loss: 4.8332 - val_loss: 5.5519 - 173ms/epoch - 4ms/step
# Epoch 75/1000
# 47/47 - 0s - loss: 4.7165 - val_loss: 5.1638 - 134ms/epoch - 3ms/step
# Epoch 76/1000
# 47/47 - 0s - loss: 4.5862 - val_loss: 5.2428 - 166ms/epoch - 4ms/step
# Epoch 77/1000
# 47/47 - 0s - loss: 4.4839 - val_loss: 4.8523 - 128ms/epoch - 3ms/step
# Epoch 78/1000
# 47/47 - 0s - loss: 4.2942 - val_loss: 4.7170 - 168ms/epoch - 4ms/step
# Epoch 79/1000
# 47/47 - 0s - loss: 4.1338 - val_loss: 4.5064 - 143ms/epoch - 3ms/step
# Epoch 80/1000
# 47/47 - 0s - loss: 4.0139 - val_loss: 4.6257 - 118ms/epoch - 3ms/step
# Epoch 81/1000
# 47/47 - 0s - loss: 3.9153 - val_loss: 4.2478 - 128ms/epoch - 3ms/step
# Epoch 82/1000
# 47/47 - 0s - loss: 3.7871 - val_loss: 4.0853 - 125ms/epoch - 3ms/step
# Epoch 83/1000
# 47/47 - 0s - loss: 3.6164 - val_loss: 4.1697 - 132ms/epoch - 3ms/step
# Epoch 84/1000
# 47/47 - 0s - loss: 3.5127 - val_loss: 3.8005 - 136ms/epoch - 3ms/step
# Epoch 85/1000
# 47/47 - 0s - loss: 3.3982 - val_loss: 3.6666 - 118ms/epoch - 3ms/step
# Epoch 86/1000
# 47/47 - 0s - loss: 3.2177 - val_loss: 3.4908 - 129ms/epoch - 3ms/step
# Epoch 87/1000
# 47/47 - 0s - loss: 3.1533 - val_loss: 3.4119 - 131ms/epoch - 3ms/step
# Epoch 88/1000
# 47/47 - 0s - loss: 3.0064 - val_loss: 3.3451 - 164ms/epoch - 3ms/step
# Epoch 89/1000
# 47/47 - 0s - loss: 2.8837 - val_loss: 3.1603 - 173ms/epoch - 4ms/step
# Epoch 90/1000
# 47/47 - 0s - loss: 2.7234 - val_loss: 3.0429 - 135ms/epoch - 3ms/step
# Epoch 91/1000
# 47/47 - 0s - loss: 2.6117 - val_loss: 2.9331 - 125ms/epoch - 3ms/step
# Epoch 92/1000
# 47/47 - 0s - loss: 2.5723 - val_loss: 2.9957 - 124ms/epoch - 3ms/step
# Epoch 93/1000
# 47/47 - 0s - loss: 2.4081 - val_loss: 2.6104 - 123ms/epoch - 3ms/step
# Epoch 94/1000
# 47/47 - 0s - loss: 2.3244 - val_loss: 2.5721 - 138ms/epoch - 3ms/step
# Epoch 95/1000
# 47/47 - 0s - loss: 2.2744 - val_loss: 2.4160 - 168ms/epoch - 4ms/step
# Epoch 96/1000
# 47/47 - 0s - loss: 2.1189 - val_loss: 2.3188 - 130ms/epoch - 3ms/step
# Epoch 97/1000
# 47/47 - 0s - loss: 2.0081 - val_loss: 2.3423 - 121ms/epoch - 3ms/step
# Epoch 98/1000
# 47/47 - 0s - loss: 1.9348 - val_loss: 2.1259 - 124ms/epoch - 3ms/step
# Epoch 99/1000
# 47/47 - 0s - loss: 1.8641 - val_loss: 2.0705 - 137ms/epoch - 3ms/step
# Epoch 100/1000
# 47/47 - 0s - loss: 1.7826 - val_loss: 2.0736 - 121ms/epoch - 3ms/step
# Epoch 101/1000
# 47/47 - 0s - loss: 1.6737 - val_loss: 2.0249 - 160ms/epoch - 3ms/step
# Epoch 102/1000
# 47/47 - 0s - loss: 1.7045 - val_loss: 1.8737 - 130ms/epoch - 3ms/step
# Epoch 103/1000
# 47/47 - 0s - loss: 1.6641 - val_loss: 2.0097 - 178ms/epoch - 4ms/step
# Epoch 104/1000
# 47/47 - 0s - loss: 1.4973 - val_loss: 1.6971 - 119ms/epoch - 3ms/step
# Epoch 105/1000
# 47/47 - 0s - loss: 1.4804 - val_loss: 1.5684 - 131ms/epoch - 3ms/step
# Epoch 106/1000
# 47/47 - 0s - loss: 1.3806 - val_loss: 1.5613 - 172ms/epoch - 4ms/step
# Epoch 107/1000
# 47/47 - 0s - loss: 1.3314 - val_loss: 1.4327 - 179ms/epoch - 4ms/step
# Epoch 108/1000
# 47/47 - 0s - loss: 1.2912 - val_loss: 1.3780 - 255ms/epoch - 5ms/step
# Epoch 109/1000
# 47/47 - 0s - loss: 1.1926 - val_loss: 1.3941 - 217ms/epoch - 5ms/step
# Epoch 110/1000
# 47/47 - 0s - loss: 1.1295 - val_loss: 1.2979 - 244ms/epoch - 5ms/step
# Epoch 111/1000
# 47/47 - 0s - loss: 1.1002 - val_loss: 1.1905 - 190ms/epoch - 4ms/step
# Epoch 112/1000
# 47/47 - 0s - loss: 1.0357 - val_loss: 1.1512 - 231ms/epoch - 5ms/step
# Epoch 113/1000
# 47/47 - 0s - loss: 1.0118 - val_loss: 1.1609 - 185ms/epoch - 4ms/step
# Epoch 114/1000
# 47/47 - 0s - loss: 0.9667 - val_loss: 1.1263 - 200ms/epoch - 4ms/step
# Epoch 115/1000
# 47/47 - 0s - loss: 0.9341 - val_loss: 1.0177 - 250ms/epoch - 5ms/step
# Epoch 116/1000
# 47/47 - 0s - loss: 0.8884 - val_loss: 0.9988 - 238ms/epoch - 5ms/step
# Epoch 117/1000
# 47/47 - 0s - loss: 0.8481 - val_loss: 0.9587 - 250ms/epoch - 5ms/step
# Epoch 118/1000
# 47/47 - 0s - loss: 0.8155 - val_loss: 0.9413 - 181ms/epoch - 4ms/step
# Epoch 119/1000
# 47/47 - 0s - loss: 0.7812 - val_loss: 0.9062 - 131ms/epoch - 3ms/step
# Epoch 120/1000
# 47/47 - 0s - loss: 0.7967 - val_loss: 0.8833 - 126ms/epoch - 3ms/step
# Epoch 121/1000
# 47/47 - 0s - loss: 0.7216 - val_loss: 0.8739 - 124ms/epoch - 3ms/step
# Epoch 122/1000
# 47/47 - 0s - loss: 0.7094 - val_loss: 0.8349 - 121ms/epoch - 3ms/step
# Epoch 123/1000
# 47/47 - 0s - loss: 0.6794 - val_loss: 0.8350 - 112ms/epoch - 2ms/step
# Epoch 124/1000
# 47/47 - 0s - loss: 0.6700 - val_loss: 0.7991 - 144ms/epoch - 3ms/step
# Epoch 125/1000
# 47/47 - 0s - loss: 0.6672 - val_loss: 0.7791 - 134ms/epoch - 3ms/step
# Epoch 126/1000
# 47/47 - 0s - loss: 0.6603 - val_loss: 0.7516 - 134ms/epoch - 3ms/step
# Epoch 127/1000
# 47/47 - 0s - loss: 0.6475 - val_loss: 0.7889 - 124ms/epoch - 3ms/step
# Epoch 128/1000
# 47/47 - 0s - loss: 0.6090 - val_loss: 0.7280 - 146ms/epoch - 3ms/step
# Epoch 129/1000
# 47/47 - 0s - loss: 0.6362 - val_loss: 0.7099 - 131ms/epoch - 3ms/step
# Epoch 130/1000
# 47/47 - 0s - loss: 0.5979 - val_loss: 0.8177 - 137ms/epoch - 3ms/step
# Epoch 131/1000
# 47/47 - 0s - loss: 0.5820 - val_loss: 0.6973 - 126ms/epoch - 3ms/step
# Epoch 132/1000
# 47/47 - 0s - loss: 0.5757 - val_loss: 0.7377 - 117ms/epoch - 2ms/step
# Epoch 133/1000
# 47/47 - 0s - loss: 0.5531 - val_loss: 0.7094 - 154ms/epoch - 3ms/step
# Epoch 134/1000
# 47/47 - 0s - loss: 0.5509 - val_loss: 0.6659 - 112ms/epoch - 2ms/step
# Epoch 135/1000
# 47/47 - 0s - loss: 0.5663 - val_loss: 0.6567 - 121ms/epoch - 3ms/step
# Epoch 136/1000
# 47/47 - 0s - loss: 0.5304 - val_loss: 0.6691 - 115ms/epoch - 2ms/step
# Epoch 137/1000
# 47/47 - 0s - loss: 0.5443 - val_loss: 0.6432 - 112ms/epoch - 2ms/step
# Epoch 138/1000
# 47/47 - 0s - loss: 0.5275 - val_loss: 0.6411 - 109ms/epoch - 2ms/step
# Epoch 139/1000
# 47/47 - 0s - loss: 0.5449 - val_loss: 0.6428 - 171ms/epoch - 4ms/step
# Epoch 140/1000
# 47/47 - 0s - loss: 0.5329 - val_loss: 0.6381 - 171ms/epoch - 4ms/step
# Epoch 141/1000
# 47/47 - 0s - loss: 0.5076 - val_loss: 0.6524 - 127ms/epoch - 3ms/step
# Epoch 142/1000
# 47/47 - 0s - loss: 0.5160 - val_loss: 0.6136 - 122ms/epoch - 3ms/step
# Epoch 143/1000
# 47/47 - 0s - loss: 0.5154 - val_loss: 0.6183 - 144ms/epoch - 3ms/step
# Epoch 144/1000
# 47/47 - 0s - loss: 0.4919 - val_loss: 0.6184 - 147ms/epoch - 3ms/step
# Epoch 145/1000
# 47/47 - 0s - loss: 0.4950 - val_loss: 0.6248 - 129ms/epoch - 3ms/step
# Epoch 146/1000
# 47/47 - 0s - loss: 0.5054 - val_loss: 0.6139 - 186ms/epoch - 4ms/step
# Epoch 147/1000
# 47/47 - 0s - loss: 0.4949 - val_loss: 0.5974 - 172ms/epoch - 4ms/step
# Epoch 148/1000
# 47/47 - 0s - loss: 0.4981 - val_loss: 0.5822 - 124ms/epoch - 3ms/step
# Epoch 149/1000
# 47/47 - 0s - loss: 0.4830 - val_loss: 0.6317 - 139ms/epoch - 3ms/step
# Epoch 150/1000
# 47/47 - 0s - loss: 0.4898 - val_loss: 0.6330 - 165ms/epoch - 4ms/step
# Epoch 151/1000
# 47/47 - 0s - loss: 0.4872 - val_loss: 0.6042 - 130ms/epoch - 3ms/step
# Epoch 152/1000
# 47/47 - 0s - loss: 0.4771 - val_loss: 0.5715 - 137ms/epoch - 3ms/step
# Epoch 153/1000
# 47/47 - 0s - loss: 0.4902 - val_loss: 0.6405 - 140ms/epoch - 3ms/step
# Epoch 154/1000
# 47/47 - 0s - loss: 0.4689 - val_loss: 0.5821 - 147ms/epoch - 3ms/step
# Epoch 155/1000
# 47/47 - 0s - loss: 0.4694 - val_loss: 0.5689 - 130ms/epoch - 3ms/step
# Epoch 156/1000
# 47/47 - 0s - loss: 0.4700 - val_loss: 0.5806 - 117ms/epoch - 2ms/step
# Epoch 157/1000
# 47/47 - 0s - loss: 0.4532 - val_loss: 0.5592 - 136ms/epoch - 3ms/step
# Epoch 158/1000
# 47/47 - 0s - loss: 0.4603 - val_loss: 0.5609 - 166ms/epoch - 4ms/step
# Epoch 159/1000
# 47/47 - 0s - loss: 0.4648 - val_loss: 0.5581 - 131ms/epoch - 3ms/step
# Epoch 160/1000
# 47/47 - 0s - loss: 0.4552 - val_loss: 0.6657 - 153ms/epoch - 3ms/step
# Epoch 161/1000
# 47/47 - 0s - loss: 0.4744 - val_loss: 0.6312 - 133ms/epoch - 3ms/step
# Epoch 162/1000
# 47/47 - 0s - loss: 0.4696 - val_loss: 0.5482 - 137ms/epoch - 3ms/step
# Epoch 163/1000
# 47/47 - 0s - loss: 0.5283 - val_loss: 0.5671 - 176ms/epoch - 4ms/step
# Epoch 164/1000
# 47/47 - 0s - loss: 0.4510 - val_loss: 0.5633 - 124ms/epoch - 3ms/step
# Epoch 165/1000
# 47/47 - 0s - loss: 0.4486 - val_loss: 0.5368 - 140ms/epoch - 3ms/step
# Epoch 166/1000
# 47/47 - 0s - loss: 0.4607 - val_loss: 0.6219 - 132ms/epoch - 3ms/step
# Epoch 167/1000
# 47/47 - 0s - loss: 0.4590 - val_loss: 0.5766 - 139ms/epoch - 3ms/step
# Epoch 168/1000
# 47/47 - 0s - loss: 0.4669 - val_loss: 0.5625 - 140ms/epoch - 3ms/step
# Epoch 169/1000
# 47/47 - 0s - loss: 0.4410 - val_loss: 0.5288 - 139ms/epoch - 3ms/step
# Epoch 170/1000
# 47/47 - 0s - loss: 0.4354 - val_loss: 0.5328 - 128ms/epoch - 3ms/step
# Epoch 171/1000
# 47/47 - 0s - loss: 0.4240 - val_loss: 0.5435 - 116ms/epoch - 2ms/step
# Epoch 172/1000
# 47/47 - 0s - loss: 0.4223 - val_loss: 0.5577 - 132ms/epoch - 3ms/step
# Epoch 173/1000
# 47/47 - 0s - loss: 0.4413 - val_loss: 0.5684 - 131ms/epoch - 3ms/step
# Epoch 174/1000
# Restoring model weights from the end of the best epoch: 169.
# 47/47 - 0s - loss: 0.4359 - val_loss: 0.5292 - 144ms/epoch - 3ms/step
# Epoch 174: early stopping

# %% [markdown]
# ## Mean Square Error
#
# The mean square error (MSE) is the sum of the squared differences between the prediction ($\hat{y}$) and the expected ($y$).  MSE values are not of a particular unit. If an MSE value has decreased for a model, that is good. However, beyond this, there is not much more you can determine. We seek to achieve low MSE values. The following equation demonstrates how to calculate MSE.
#
# $$ \mbox{MSE} = \frac{1}{n} \sum_{i=1}^n \left(\hat{y}_i - y_i\right)^2 $$
#
# The following code calculates the MSE on the predictions from the neural network.

# %%
from sklearn import metrics

# Predict
pred = model.predict(x_test)

# Measure MSE error.  
score = metrics.mean_squared_error(pred,y_test)
print("Final score (MSE): {}".format(score))
# Out:
# 16/16 [==============================] - 0s 2ms/step
# Final score (MSE): 0.5287829361721306

# %% [markdown]
# ## Root Mean Square Error
#
# The root mean square (RMSE) is essentially the square root of the MSE. Because of this, the RMSE error is in the same units as the training data outcome. We desire Low RMSE values. The following equation calculates RMSE.
#
# $$ \mbox{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^n \left(\hat{y}_i - y_i\right)^2} $$

# %%
import numpy as np

# Measure RMSE error.  RMSE is common for regression.
score = np.sqrt(metrics.mean_squared_error(pred,y_test))
print("Final score (RMSE): {}".format(score))
# Out:
# Final score (RMSE): 0.7271746256382511

# %% [markdown]
# ## Lift Chart
#
# We often visualize the results of regression with a lift chart. To generate a lift chart, perform the following activities:
#
# * Sort the data by expected output and plot these values.
# * For every point on the x-axis, plot that same data point's predicted value in another color.
# * The x-axis is just 0 to 100% of the dataset. The expected always starts low and ends high.
# * The y-axis is ranged according to the values predicted.
#
# You can interpret the lift chart as follows:
#
# * The expected and predict lines should be close. Notice where one is above the other.
# * The below chart is the most accurate for lower ages.

# %%
# Regression chart.
def chart_regression(pred, y, sort=True):
    t = pd.DataFrame({'pred': pred, 'y': y.flatten()})
    if sort:
        t.sort_values(by=['y'], inplace=True)
    plt.plot(t['y'].tolist(), label='expected')
    plt.plot(t['pred'].tolist(), label='prediction')
    plt.ylabel('output')
    plt.legend()
    plt.show()
    
# Plot the chart
chart_regression(pred.flatten(),y_test)
